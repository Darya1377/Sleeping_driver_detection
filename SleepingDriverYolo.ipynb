# %%
# !pip install torch torchvision torchaudio -f https://download.pytorch.org/whl/lts/1.8/torch_lts.html
# Out:
# Looking in links: https://download.pytorch.org/whl/lts/1.8/torch_lts.html
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15990, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 15990 (delta 15), reused 16 (delta 11), pack-reused 15967
# Receiving objects: 100% (15990/15990), 14.58 MiB | 15.55 MiB/s, done.
# Resolving deltas: 100% (10981/10981), done.

# %%
# !cd yolov5

# %%
# !pip install -r /content/yolov5/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.5/189.5 kB 3.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 618.1/618.1 kB 37.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 10.8 MB/s eta 0:00:00
# ...

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/hub.py:286: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# YOLOv5 🚀 2023-9-20 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...
# 100%|██████████| 14.1M/14.1M [00:00<00:00, 295MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# ...

# %%
# !unzip /content/data.zip
# Out:
# Archive:  /content/data.zip
#   inflating: data/classes.txt
#    creating: data/images/
#   inflating: data/images/10065.jpg
#   inflating: data/images/10074.jpg
#   inflating: data/images/10106.jpg
#   inflating: data/images/10111.jpg
#   inflating: data/images/10112.jpg
#   inflating: data/images/1017.jpg
#   inflating: data/images/10259.jpg
#   inflating: data/images/10288.jpg
#   inflating: data/images/10301.jpg
#   inflating: data/images/10304.jpg
#   inflating: data/images/10310.jpg
#   inflating: data/images/10329.jpg
#   inflating: data/images/10338.jpg
#   inflating: data/images/10462.jpg
#   inflating: data/images/10464.jpg
#   inflating: data/images/10476.jpg
#   inflating: data/images/10489.jpg
#   inflating: data/images/10511.jpg
#   inflating: data/images/10515.jpg
#   inflating: data/images/10528.jpg
#   inflating: data/images/10648.jpg
#   inflating: data/images/10660.jpg
#   inflating: data/images/10672.jpg
#   inflating: data/images/10674.jpg
# ...

# %%
# !python /content/yolov5/train.py --img 320 --batch 16 --epochs 15 --data /content/dataset.yaml --weights yolov5s.pt --workers 2
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/dataset.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=500, batch_size=16, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=2, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-223-g005dcfa Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...
